# %% [markdown]
# # Git & GitHub
# -git add . = lägger till alla filer för att sparas
#
# -git commit = git commit -m "kommentar" sparar projektet i ens snapshot
#
# -git push = lägger till vår snapshot på github

# %%
print("någonting nytt")
# Out:
# någonting nytt

# %% [markdown]
# Någonting mer
